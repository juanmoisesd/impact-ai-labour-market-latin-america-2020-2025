# %% [markdown]
# # Impact of Artificial Intelligence on the Labour Market in Latin America (2020-2025)
#
# **DOI:** https://doi.org/10.5281/zenodo.19211739
# **Author:** de la Serna, Juan Moisés
# **Year:** 2025

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Analysis: AI Impact on Labour Market - Latin America 2020-2025")

# %% [markdown]
# ## 1. Automation by Sector
#
# Analysis of automation risk indices by economic sector across Latin American countries.

# %%
# df_automation = pd.read_csv("automation_by_sector.csv")
# df_automation.head()

# %% [markdown]
# ## 2. Labour Displacement Projections
#
# Modelling job displacement scenarios for 2025-2030.

# %%
# df_displacement = pd.read_csv("labour_displacement.csv")
# df_displacement.describe()

# %% [markdown]
# ## How to Cite
#
# ```
# de la Serna, Juan Moisés (2025). Impact of Artificial Intelligence on the Labour Market in Latin America (2020-2025). Zenodo. https://doi.org/10.5281/zenodo.19211739
# ```
